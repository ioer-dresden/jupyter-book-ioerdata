# %% [markdown]
# # 🗺️ Mission 6: Map the City
#
# ```{raw} html
# <div id="mission-6-gate"></div>
#
# <script>
# const mission5Completed =
#   localStorage.getItem("urban_data_mission_5_completed");
#
# if (mission5Completed === "true") {
#
#   document.getElementById("mission-6-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#
#       <p>Welcome back, Urban Data Investigator.</p>
#
#       <p>
#       You completed <strong>Mission 5: Create Visual Evidence</strong>
#       and earned the <strong>Visual Evidence Creator</strong> badge.
#       </p>
#
#       <p>
#       Now it is time to discover where the patterns occur. In this mission,
#       you will map urban forest indicators across Berlin and explore
#       their spatial patterns.
#       </p>
#
#       <p style="margin-top: 16px;">
#         <a href="311_mission6_content.html"
#            style="display: inline-block;
#                   padding: 12px 18px;
#                   background-color: #1565C0;
#                   color: white;
#                   text-decoration: none;
#                   border-radius: 8px;
#                   font-weight: bold;">
#           🚀 Start Mission 6
#         </a>
#       </p>
#     </div>
#   `;
#
# } else {
#
#   document.getElementById("mission-6-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#
#       <p>This mission is currently locked.</p>
#
#       <p>
#       Complete <strong>Mission 5: Create Visual Evidence</strong>
#       before continuing.
#       </p>
#
#       <p>
#       Return to Mission 5 and click
#       <strong>Complete Mission 5</strong> at the end of the page.
#       </p>
#     </div>
#   `;
#
# }
# </script>
