# %% [markdown]
# # 🧠 Mission 3: Understand the Data
#
# ```{raw} html
# <div id="mission-3-gate"></div>
#
# <script>
# const mission2Completed =
#   localStorage.getItem("urban_data_mission_2_completed");
#
# if (mission2Completed === "true") {
#
#   document.getElementById("mission-3-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#
#       <p>Welcome back, Urban Data Investigator.</p>
#
#       <p>
#       You completed <strong>Mission 2</strong> and earned the
#       <strong>Package Detective</strong> badge.
#       </p>
#
#       <p>
#       🚧 Mission 3 is currently under construction.
#       </p>
#
#       <p>
#       Soon, you will learn how to:
#       </p>
#
#       <ul>
#         <li>interpret dataset variables</li>
#         <li>understand attributes and indicators</li>
#         <li>identify useful columns for analysis</li>
#         <li>prepare data for visualization</li>
#       </ul>
#     </div>
#   `;
#
# } else {
#
#   document.getElementById("mission-3-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#
#       <p>This mission is locked.</p>
#
#       <p>
#       Complete <strong>Mission 2: Inspect the Replication Package</strong>
#       first.
#       </p>
#
#       <p>
#       Return to Mission 2 and click <strong>Complete Mission 2</strong>.
#       </p>
#     </div>
#   `;
#
# }
# </script>
# ```
