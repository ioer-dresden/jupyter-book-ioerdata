# %% [markdown]
# # Disclaimer

# %% [markdown]
# This book demonstrates how to access ioerDATA using Python via the API (Application Programming Interface). Although we have endeavored to ensure the accuracy of all information and codes at the time of writing, please bear in mind that errors may occur. Note that the Python code examples provided here represent just one of many possible approaches.
#
# Should you discover an error, please notify us via [fdz@ioer.de](mailto:fdz@ioer.de) so that we can fix it.
