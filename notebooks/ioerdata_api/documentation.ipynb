# %% [markdown]
# # Documentation
# This documentation will guide you through everything you need to know to use and reproduce this training material, starting from the environment setup to the final outputs.
# - Purpose & scope of the training
# - Audience (prerequisites, what you expect users to know)
# - Overview of components (data API, notebooks, visualizations)

# %% [markdown]
# # Environment Setup
# - Tools & software requirements (Python version, libraries, extensions)
# - How the environment is created (e.g. Alex setup using CartoLab, Docker, etc.)
# - How a new user can replicate that (installation steps, dependencies)
# ### Input required from Alex
# - Login to GitLab at TU Chemnitz (requires 2FA)
# - Find the quick start here - https://cartolab.fdz.ioer.info/quickstart/
# - Find the concept here - https://cartolab.fdz.ioer.info/concept/

# %% [markdown]
# # Structure
# - User should work on the "staging" branch
# - Change file structure in  _toc.yml
# - Check the progress here - https://gitlab.hrz.tu-chemnitz.de/ioer/fdz/training/jupyter-book-ioerdata/-/commits/staging?ref_type=HEADS
# - Check the pipeline here - https://gitlab.hrz.tu-chemnitz.de/ioer/fdz/training/jupyter-book-ioerdata/-/pipelines
# - Check the deployed version here - https://stag.ioerdata.training.fdz.ioer.info/ and https://ioerdata.training.fdz.ioer.info/
# - press CTRL+f5 to force refresh (if the change is not visible)
# - Basic steps are available here - https://training.fdz.ioer.info/CONTRIBUTING.html#jupyter-collaborative-editing

# %% [markdown]
# # Data Access / Download via IOER API
#
# - What is the IOER data API (endpoint, authentication, etc.)
# - How to query / call it (parameters, filters, limits)
# - Example code blocks with explanations
# - What the downloaded data contains (schema, columns, metadata)
#
# - use worker_env instead of python3 to avoid additional dependencies. Details can be found here - https://cartolab.fdz.ioer.info/jupyter/

# %% [markdown]
# # Data Inspection & Understanding
#
# - Methods to inspect the data (e.g. head(), info(), checking nulls, types)
# - Data dictionary / metadata explanation
# - Domain-specific notes (spatial reference system, units, categories)

# %% [markdown]
# # Basic Data Analysis
#
# - Summary statistics, aggregations
# - Filtering, grouping, subsetting
# - Handling missing data, data cleaning as needed

# %% [markdown]
# # Basic Visualization
#
# - Plotting with standard libraries (matplotlib, seaborn, etc.)
# - Spatial visualizations (e.g. using geopandas, folium, etc.)
# - Example visualizations and explanations

# %% [markdown]
# # Advanced Visualization
#
# - More complex viz (interactive maps, dashboards, animations, multi-layer maps)
# - Tools used for advanced viz (e.g. Plotly, Kepler, deck.gl, ipyleaflet)
# - Code examples + commentary

# %% [markdown]
# # Putting it Together / Workflow
#
# - Example full workflow from data download → clean → analyze → visualize
# - Troubleshooting & FAQs

# %% [markdown]
# # Troubleshooting & FAQs
#
# - Common errors and how to fix
# - Tips for performance (e.g. managing large spatial data)
# - Edge cases

# %% [markdown]
# # Appendices / Reference Materials
#
# - Full list of API endpoints & specs
# - Library reference (functions used, helper utilities)
# - File / folder structure (how notebooks, data, results are organized)
# - Change Log / Versioning

# %% [markdown]
# # Track what changes you make over time
#
# - Date, author, description of changeGlossary of terms
