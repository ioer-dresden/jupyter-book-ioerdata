# %% [markdown]
# ```{raw} html
#
# <!-- ================================================= -->
# <!-- 🔒 / 🔓 Mission 3 Gate -->
# <!-- ================================================= -->
#
# <div id="mission-3-gate"></div>
#
# <!-- ================================================= -->
# <!-- 🚧 Mission 3 Content -->
# <!-- ================================================= -->
#
# <div id="mission-3-content" style="display: none;">
#
# # 🧠 Mission 3: Understand the Data
#
# ```{admonition} 🚧 Mission Under Construction
# :class: warning
#
# Mission 3 is currently under construction.
#
# Soon, you will learn how to:
#
# - 📊 interpret dataset variables
# - 🧾 understand attributes and indicators
# - 🔍 identify meaningful variables
# - 🧠 think critically about data interpretation
#
# 🏗️ Your investigation continues soon.
# ```
#
# </div>
#
# <!-- ================================================= -->
# <!-- 🎮 Unlock Logic -->
# <!-- ================================================= -->
#
# <script>
#
# const mission2Completed =
#   localStorage.getItem(
#     "urban_data_mission_2_completed"
#   );
#
# // =================================================
# // 🔓 If Mission 2 completed
# // =================================================
#
# if (mission2Completed === "true") {
#
#   // Show Mission 3 content
#   document.getElementById(
#     "mission-3-content"
#   ).style.display = "block";
#
#   // Show unlock message
#   document.getElementById(
#     "mission-3-gate"
#   ).innerHTML = `
#
#     <div class="admonition tip">
#
#       <p class="admonition-title">
#       🔓 Mission Unlocked
#       </p>
#
#       <p>
#       Welcome back, Urban Data Investigator.
#       </p>
#
#       <p>
#       You successfully completed Mission 2 and unlocked Mission 3.
#       </p>
#
#       <p>
#       🏅 New Badge Earned:
#       <strong>Package Detective</strong>
#       </p>
#
#     </div>
#
#   `;
#
# }
#
# // =================================================
# // 🔒 Otherwise keep locked
# // =================================================
#
# else {
#
#   document.getElementById(
#     "mission-3-gate"
#   ).innerHTML = `
#
#     <div class="admonition warning">
#
#       <p class="admonition-title">
#       🔒 Mission Locked
#       </p>
#
#       <p>
#       Complete
#       <strong>Mission 2: Inspect the Replication Package</strong>
#       first.
#       </p>
#
#       <p>
#       Return to Mission 2 and click:
#       <strong>Complete Mission 2</strong>
#       </p>
#
#     </div>
#
#   `;
#
# }
#
# </script>
#
# ```
