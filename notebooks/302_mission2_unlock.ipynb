# %% [markdown]
# # 🔍 Mission 2: Inspect the Replication Package
#
# ```{raw} html
# <div id="mission-2-gate"></div>
#
# <script>
# const mission1Completed =
#   localStorage.getItem("urban_data_mission_1_completed");
#
# if (mission1Completed === "true") {
#
#   document.getElementById("mission-2-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#
#       <p>Welcome back, Urban Data Investigator.</p>
#
#       <p>
#       You completed <strong>Mission 1: Locate and Retrieve the Dataset</strong>.
#       Mission 2 is now available.
#       </p>
#
#       <p>
#       In this mission, you will inspect the replication package and understand
#       how documentation, code, data, and outputs fit together.
#       </p>
#
#       <p style="margin-top: 16px;">
#         <a href="302_mission2_content.html"
#            style="display: inline-block;
#                   padding: 12px 18px;
#                   background-color: #1565C0;
#                   color: white;
#                   text-decoration: none;
#                   border-radius: 8px;
#                   font-weight: bold;">
#           🚀 Start Mission 2
#         </a>
#       </p>
#     </div>
#   `;
#
# } else {
#
#   document.getElementById("mission-2-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#
#       <p>This mission is currently locked.</p>
#
#       <p>
#       Complete <strong>Mission 1: Locate and Retrieve the Dataset</strong>
#       before continuing.
#       </p>
#
#       <p>
#       Return to Mission 1 and click
#       <strong>Complete Mission 1</strong> at the end of the page.
#       </p>
#     </div>
#   `;
#
# }
# </script>
# ```
