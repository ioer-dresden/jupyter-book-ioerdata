# %% [markdown]
# # Data Access
# ```{admonition} Accessing Restricted data on ioerDATA
# :class: note
#
# When working with research data, not everything can always be shared openly. This section explains how **restricted files** are handled on **ioerDATA**, and how you can work with them in a **transparent, ethical, and reproducible** way.
#
# A restricted file on ioerDATA is a dataset with **limited access** to its registered users.
# ```

# %% [markdown]
# ```{admonition} Why are some variables restricted?
# :class: note, dropdown
# Socio-economic variables such as **GDP-related indicators** can be sensitive, especially when they:
# - originate from licensed statistical sources
# - could allow indirect identification when combined with other data
# - are subject to usage agreements with data providers
#
# Restricting such variables is a common and accepted practice in research data infrastructures. Learning how to **work correctly with these restrictions** is a key goal of this training.
# ```

# %% [markdown]
# ```{admonition} Practical workflow: how to access restricted files
# :class: note
#
# If you want to work with restricted files on ioerDATA, please follow the recommended process below:
# 1. Create an ioerDATA account and log in
#    - Register for an account on the ioerDATA platform. [sign‑up page](https://data.fdz.ioer.de/dataverseuser.xhtml?editMode=CREATE&redirectPage=%2Floginpage.xhtml)
#    - Log in before attempting to download restricted files. [login page](https://data.fdz.ioer.de/loginpage.xhtml?redirectPage=dataverseuser.xhtml)
# 2. Request access to the dataset page
#    - Navigate to the dataset or replication package page
#    - locate the restricted dataset/file
#    - Click "Access Dataset" or "Access File" and follow the instructions
# 3. Use an API token for programmatic downloads
#    - An API token is a personal access key linked to your user account
#      - Click "Your Name" and follow the instructions
#    - It allows Python scripts or notebooks to authenticate securely
#    - Tokens should be stored safely, **never hard-coded**
# Once your access request is approved and your API token is configured, restricted files can be downloaded programmatically in the same way as open files.
# ```

# %% [markdown]
# ```{admonition} Fallback Route will be introduced soon!
# :class: hint, dropdown
#
# # If you do not have access (yet)
# Not having access is completely fine in a training context.
# Without access, we will switch to a clearly labeled **fallback route**, such as:
# - Synthetic (simulated) example data, or
# - Openly available proxy variables
#
# This will allow you to:
# - Learn the full workflow
# - Practice analysis and visualization
# - Understand how restricted data would be integrated
#
# At the same time, the notebook remains **honest, transparent, and reproducible.**
# ```
