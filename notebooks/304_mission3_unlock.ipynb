# %% [markdown]
# # 🧠 Mission 3: Understand the Data
#
# ```{raw} html
# <div id="mission-3-gate"></div>
#
# <script>
# const mission2Completed =
#   localStorage.getItem("urban_data_mission_2_completed");
#
# if (mission2Completed === "true") {
#
#   document.getElementById("mission-3-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#
#       <p>Welcome back, Urban Data Investigator.</p>
#
#       <p>
#       You completed <strong>Mission 2: Inspect the Replication Package</strong>
#       and earned the <strong>Package Detective</strong> badge.
#       </p>
#
#       <p>
#       In this mission, you will explore the dataset itself, understand its
#       variables, and assess its quality before beginning any analysis.
#       </p>
#
#       <p style="margin-top: 16px;">
#         <a href="305_mission3_content.html"
#            style="display: inline-block;
#                   padding: 12px 18px;
#                   background-color: #1565C0;
#                   color: white;
#                   text-decoration: none;
#                   border-radius: 8px;
#                   font-weight: bold;">
#           🚀 Start Mission 3
#         </a>
#       </p>
#     </div>
#   `;
#
# } else {
#
#   document.getElementById("mission-3-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#
#       <p>This mission is currently locked.</p>
#
#       <p>
#       Complete <strong>Mission 2: Inspect the Replication Package</strong>
#       before continuing.
#       </p>
#
#       <p>
#       Return to Mission 2 and click
#       <strong>Complete Mission 2</strong> at the end of the page.
#       </p>
#     </div>
#   `;
#
# }
# </script>
# ```
