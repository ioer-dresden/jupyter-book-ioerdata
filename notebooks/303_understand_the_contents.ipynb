# %% [markdown]
# # Mission 3: Understand the Content

# %% [markdown]
# ```{raw} html
#
# <!-- 🔒/🔓 Message will appear here -->
# <div id="mission-3-gate"></div>
#
# <!-- 🧩 Actual Mission 3 content (hidden initially) -->
# <div id="mission-3-content" style="display: none;">
#
# <h1>🧠 Mission 3: Understand the Data</h1>
#
# <div class="admonition note">
# <p class="admonition-title">🎯 Mission Brief</p>
#
# Congratulations, Investigator.
#
# You have successfully located the dataset and inspected the replication package.
#
# Now it is time to understand what the data actually contains.
#
# In this mission, you will:
#
# <ul>
# <li>📊 explore variables and attributes</li>
# <li>🧾 understand indicators and measurements</li>
# <li>🔍 identify useful columns for analysis</li>
# <li>🧠 prepare the data for future visualisation and interpretation</li>
# </ul>
#
# 🏅 <strong>Badge to unlock:</strong> Data Interpreter
#
# </div>
#
# <div class="admonition tip">
# <p class="admonition-title">🗺️ Investigator Context</p>
#
# Researchers rarely analyse data immediately.
#
# Before analysis begins, they need to understand:
#
# <ul>
# <li>what each variable represents</li>
# <li>which units are used</li>
# <li>which columns are useful</li>
# <li>which limitations exist</li>
# </ul>
#
# 👉 Understanding the data is often the most important step in the workflow.
#
# </div>
#
# <div class="admonition important">
# <p class="admonition-title">🤔 Think Before You Analyse</p>
#
# Before loading the data, ask yourself:
#
# <ul>
# <li>What does each variable represent?</li>
# <li>Which variables might be useful for visualisation?</li>
# <li>Which variables may require additional explanation?</li>
# </ul>
#
# 👉 Good researchers understand their data before producing results.
#
# </div>
#
# </div>
#
# <!-- ⚙️ Unlock logic -->
# <script>
#
# const mission2Completed =
#   localStorage.getItem("urban_data_mission_2_completed");
#
# if (mission2Completed === "true") {
#
#   // ✅ Show Mission 3 content
#   document.getElementById("mission-3-content").style.display = "block";
#
#   // 🔓 Show unlocked message
#   document.getElementById("mission-3-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#
#       <p>
#       Welcome back, Urban Data Investigator.
#       </p>
#
#       <p>
#       You successfully completed Mission 2 and earned the
#       <strong>Package Detective</strong> badge.
#       </p>
#
#       <p>
#       Your next challenge is to understand the data itself.
#       </p>
#     </div>
#   `;
#
# } else {
#
#   // 🔒 Show locked message
#   document.getElementById("mission-3-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#
#       <p>
#       This mission is locked.
#       </p>
#
#       <p>
#       Complete <strong>Mission 2: Inspect the Replication Package</strong> first.
#       </p>
#
#       <p>
#       Return to Mission 2 and click
#       <strong>Complete Mission 2</strong>.
#       </p>
#
#     </div>
#   `;
#
# }
#
# </script>
# ```

# %% [markdown]
# ```{raw} html
# <div id="mission-3-gate"></div>
#
# <div id="mission-3-protected-content" style="display: none;">
# ```

# %% [markdown]
# # Mission 3 contents test

# %% [markdown]
# ```{raw} html
# </div>
#
# <script>
# const mission2Completed =
#   localStorage.getItem("urban_data_mission_2_completed");
#
# if (mission2Completed === "true") {
#
#   document.getElementById("mission-3-protected-content").style.display = "block";
#
#   document.getElementById("mission-3-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#       <p>You completed Mission 2 and unlocked Mission 3.</p>
#     </div>
#   `;
#
# } else {
#
#   document.getElementById("mission-3-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#       <p>Complete <strong>Mission 2: Inspect the Replication Package</strong> first.</p>
#     </div>
#   `;
#
# }
# </script>
# ```
