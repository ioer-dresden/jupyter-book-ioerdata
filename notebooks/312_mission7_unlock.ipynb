# %% [markdown]
# # 🚀 Extend the Analysis
#
# ```{raw} html
# <div id="mission-7-gate"></div>
#
# <script>
# const mission6Completed =
#   localStorage.getItem("urban_data_mission_6_completed");
#
# if (mission6Completed === "true") {
#
#   document.getElementById("mission-7-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#
#       <p>Welcome back, Urban Data Investigator.</p>
#
#       <p>
#       You completed <strong>Mission 6: Map the City</strong>
#       and earned the <strong>Spatial Explorer</strong> badge.
#       </p>
#
#       <p>
#       Now it is time to follow the evidence further. In this mission,
#       you will connect canopy patterns with urban structure and
#       explore how the analysis can be extended.
#       </p>
#
#       <p style="margin-top: 16px;">
#         <a href="313_mission7_content.html"
#            style="display: inline-block;
#                   padding: 12px 18px;
#                   background-color: #1565C0;
#                   color: white;
#                   text-decoration: none;
#                   border-radius: 8px;
#                   font-weight: bold;">
#           🚀 Start Mission 7
#         </a>
#       </p>
#     </div>
#   `;
#
# } else {
#
#   document.getElementById("mission-7-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#
#       <p>This mission is currently locked.</p>
#
#       <p>
#       Complete <strong>Mission 6: Map the City</strong>
#       before continuing.
#       </p>
#
#       <p>
#       Return to Mission 6 and click
#       <strong>Complete Mission 6</strong> at the end of the page.
#       </p>
#     </div>
#   `;
#
# }
# </script>
