# %% [markdown]
# # Authors

# %% [markdown]
# This notebook was created through a collaborative effort, with contributions aligned to the [CRediT](https://www.elsevier.com/researcher/author/policies-and-guidelines/credit-author-statement) (Contributor Roles Taxonomy) standards.

# %% [markdown]
# | Name                 | Contributions    |
# | :-------------------- | ---------------- |
# | Oyshi, Marzan Tasnim | Conceptualization, Writing – Original Draft , Writing - Review & Editing, Software - Programming, Implementation of the Python code  |
# | Dunkel, Alexander    | Software          |
# | Nieswand, Maria      | Supervision, Conceptualization     |
# | Cruickshank, Claudia | Writing - Review & Editing            |
#
# We extend our special thanks to  **Bongaerts, Nicolaas** for the website design!
