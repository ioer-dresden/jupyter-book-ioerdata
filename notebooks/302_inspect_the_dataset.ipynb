# %% [markdown]
# # Mission 2: Inspect the Package

# %% [markdown]
# ```{raw} html
#
# <!-- 🔒/🔓 Message will appear here -->
# <div id="mission-2-gate"></div>
#
# <!-- 🧩 Actual Mission 2 content (hidden initially) -->
# <div id="mission-2-content" style="display: none;">
#
# <h1>🔍 Mission 2: Inspect the Replication Package</h1>
#
# <div class="admonition note">
# <p class="admonition-title">🎯 Mission Brief</p>
#
# In this mission, you will explore the internal structure of the dataset you downloaded.
#
# Your tasks:
#
# <ul>
# <li> Identify different file types </li>
# <li> Understand the purpose of each file </li>
# <li> Distinguish data, documentation, and code </li>
# <li> Interpret what is missing due to restrictions</li>
# </ul>
#
# 🏅 <strong>Badge to unlock:</strong> Package Detective
# </div>
#
# <div class="admonition tip">
# <p class="admonition-title">🗂️ Investigator Context</p>
#
# A replication package is more than just data.
#
# It usually contains:
# <ul>
# <li>data files</li>
# <li>code used in analysis</li>
# <li>documentation (README)</li>
# <li>visual outputs</li>
# </ul>
#
# 👉 Your job is to understand how these pieces fit together.
# </div>
#
# <div class="admonition important">
# <p class="admonition-title"> Think Like a Researcher 🧠</p>
#
# Before opening any file, ask:
#
# <ul>
# <li>Which file contains the main data?</li>
# <li>Which files explain the workflow?</li>
# <li>Which files help interpret results?</li>
# </ul>
#
# 👉 Good researchers explore before analyzing.
# </div>
#
# </div>
#
# <!-- ⚙️ Unlock logic -->
# <script>
# const mission1Completed = localStorage.getItem("urban_data_mission_1_completed");
#
# if (mission1Completed === "true") {
#
#   // ✅ Show Mission 2 content
#   document.getElementById("mission-2-content").style.display = "block";
#
#   // 🔓 Show unlocked message
#   document.getElementById("mission-2-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#       <p>Welcome back, Urban Data Investigator.</p>
#       <p>You have completed Mission 1 and can now continue your investigation.</p>
#     </div>
#   `;
#
# } else {
#
#   // 🔒 Show locked message
#   document.getElementById("mission-2-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#       <p>This mission is locked.</p>
#       <p>To unlock it, go back to <strong>Mission 1</strong> and click <strong>Complete Mission 1</strong> at the end.</p>
#     </div>
#   `;
#
# }
# </script>

# %% [markdown]
# ```{raw} html
# <div id="mission-2-gate"></div>
#
# <div id="mission-2-protected-content" style="display: none;">
# ```

# %% [markdown]
# # 🔍 Mission 2: Inspect the Replication Package
#
# ```{admonition} 🎯 Mission Brief
# :class: note
#
# Your investigation continues.
#
# You have successfully retrieved the dataset. Now it is time to inspect the replication package like a researcher.
#
# In this mission, you will:
#
# - 📂 identify different file types
# - 📄 distinguish documentation, code, and data
# - 🔍 determine which files are usable
# - 🧠 understand what is missing because of restrictions
#
# 🏅 **Badge to unlock:** Package Detective
# ```

# %% [markdown]
# ```{admonition} 🧠 Investigator Tip
# :class: tip
#
# Replication packages usually contain multiple components:
#
# - datasets
# - scripts or notebooks
# - documentation
# - figures or outputs
#
# Before analysis begins, researchers inspect the structure of the package to understand how everything connects.
# ```

# %% [markdown]
# ```{admonition} 🤔 Think Before You Explore
# :class: important
#
# Before opening the files, ask yourself:
#
# - Which file probably contains the main data?
# - Which file explains the workflow?
# - Which files help reproduce the analysis?
# - What might be missing because of restricted access?
# ```

# %% [markdown]
# ## 📂 Step 1: List Downloaded Files
#
# Use this cell to inspect the files downloaded from Mission 1.

# %%
from pathlib import Path

# Folder containing files downloaded in Mission 1
data_folder = Path("data/g_raw")

# Collect all files in the folder
files = sorted(data_folder.glob("*"))

print("Files in replication package:\n")

for file in files:
    print(f"- {file.name}")
# Out:
# Files in replication package:
#
# - README.md
# - lcz_2018_classcodes.csv
# - localized_assessment_of_urban_forest_structures_with_3d_indicators_replication_static.html
# - localized_assessment_of_urban_forest_structures_with_3d_indicators_replication_workflow.ipynb
# - urban_forest_3d_indicators_graphical_abstract.png

# %% [markdown]
# ```{admonition} 🔍 Investigation Checkpoint
# :class: tip
#
# You have now explored the visible structure of the replication package.
#
# Try to identify:
#
# - documentation files
# - workflow/code files
# - figures/images
# - actual research data
# ```

# %% [markdown]
# ## 📄 Step 2: Identify File Types
#
# File extensions help us understand what role each file may play in the replication package.

# %%
from collections import Counter

# Extract file extensions from the downloaded files
extensions = [file.suffix.lower() for file in files]

# Count how many times each extension appears
extension_counts = Counter(extensions)

print("File types found:\n")

for ext, count in extension_counts.items():
    label = ext if ext else "[no extension]"
    print(f"{label}: {count}")
# Out:
# File types found:
#
# .md: 1
# .csv: 1
# .html: 1
# .ipynb: 1
# .png: 1

# %% [markdown]
# ```{admonition} 💡 Understanding File Types
# :class: note
#
# Different file types usually serve different purposes:
#
# - `.md` → documentation
# - `.ipynb` → Jupyter notebooks / workflows
# - `.html` → exported reports or visual outputs
# - `.png` → figures or graphics
# - `.gpkg` → geospatial data
# - `.rds` → serialized R objects
#
# 🧠 Understanding file structure is an important research skill.
# ```

# %% [markdown]
# ## 📘 Step 3: Read the README File
#
# Many replication packages include a README file explaining the dataset structure and workflow.

# %%
# Path to README file
readme_path = data_folder / "README.md"

# Check whether README exists before reading it
if readme_path.exists():
    with open(readme_path, "r", encoding="utf-8") as f:
        readme_text = f.read()

    print(readme_text[:1500])
else:
    print("README.md was not found in the downloaded files.")
# Out:
# # Replication Data for: Localized assessment of urban forest structures with 3D indicators
#
# ## General Information
#
# ### Description:
# The dataset includes all data and source code required to reproduce the analysis presented in the study
# *Localized Assessment of Urban Forest Structures with 3D Indicators*, published in *Ecological Indicators* (2026).
# Pre-processed GeoPackages (.gpkg) for Amsterdam and Berlin contain canopy-height and building-height values on a 100 m grid. These  values were derived from publicly available canopy-height and building-height datasets. The supplied grid cells are classified according to the Local Climate Zone (LCZ) scheme, allowing direct integration into the analysis workflow.
# An interactive Jupyter Notebook guides users through the complete analysis, following the structure of the manuscript. A dynamic map viewer provides zoom, pan, and layer-overlay controls for interactive exploration of the results.
# A static, read-only HTML report presents all figures, tables, and map screenshots without requiring code execution.
#
# Click the link below to launch this repository in an executable Binder environment in your browser:
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/markusmnzngr/urban-forest-structure-3d-indicators-replication/HEAD?urlpath=%2Fdoc%2Ftree%2F%2Fnotebooks%2Flocalized_assessment_of_urban_forest_structures_with_3d_indicators_replication_workflow.ipynb)
# Please note that building the Binder enviro

# %% [markdown]
# ```{admonition} 🧠 Think Like a Researcher
# :class: important
#
# Good researchers rarely start with analysis immediately.
#
# They first ask:
#
# - What does the README explain?
# - Which files are important?
# - Which workflow was originally used?
# - Which components are missing?
# ```

# %% [markdown]
# ## 🔒 Step 4: Identify Restricted Components
#
# Some files were not downloaded because they are restricted.
#
# This does not mean they are irrelevant. Restricted files may contain important analysis data, but they require permission before use.

# %%
# Restricted files identified during Mission 1
restricted_files = [
    "amsterdam_3D_canopy_stats_lczv3_grid100m_lau2021_epsg28992.gpkg",
    "amsterdam_gwr_canopy_indicators_adaptive_bandwidth_12_bisquare_kernel.rds",
    "berlin_3D_canopy_stats_lczv3_grid100m_urau2021_epsg25833.gpkg",
    "berlin_gwr_canopy_indicators_adaptive_bandwidth_12_bisquare_kernel.rds"
]

print("Restricted files:\n")

for file in restricted_files:
    print(f"- {file}")
# Out:
# Restricted files:
#
# - amsterdam_3D_canopy_stats_lczv3_grid100m_lau2021_epsg28992.gpkg
# - amsterdam_gwr_canopy_indicators_adaptive_bandwidth_12_bisquare_kernel.rds
# - berlin_3D_canopy_stats_lczv3_grid100m_urau2021_epsg25833.gpkg
# - berlin_gwr_canopy_indicators_adaptive_bandwidth_12_bisquare_kernel.rds

# %% [markdown]
# ```{admonition} 🤔 Investigator Challenge
# :class: important
#
# Answer these questions:
#
# - Which file seems most important for analysis?
# - Which files support reproducibility?
# - What limitations arise when some files are restricted?
#
# 🧠 Researchers must document access limitations transparently.
# ```

# %% [markdown]
# ```{raw} html
# <div class="admonition tip">
#   <p class="admonition-title">🎉 Mission Complete — Badge Unlocked!</p>
#
#   <h3>🏆 Package Detective</h3>
#
#   <p>You successfully inspected the replication package.</p>
#
#   <ul>
#     <li>✔ File structure explored</li>
#     <li>✔ Documentation identified</li>
#     <li>✔ Workflow files recognized</li>
#     <li>✔ Restricted components understood</li>
#   </ul>
#
#   <p><strong>Status:</strong> Mission 2 complete</p>
#
#   <button onclick="completeMission2()" style="padding: 10px 16px; font-weight: bold; border-radius: 6px; cursor: pointer;">
#     ✅ Complete Mission 2
#   </button>
#
#   <p id="mission-2-complete-message" style="font-weight: bold; margin-top: 12px;"></p>
# </div>
#
# <script>
# function completeMission2() {
#   // This token unlocks Mission 3
#   localStorage.setItem("urban_data_mission_2_completed", "true");
#
#   // Optional: store badge name
#   localStorage.setItem("urban_data_badge_2", "Package Detective");
#
#   // Optional: store completion time
#   localStorage.setItem("urban_data_mission_2_completed_at", new Date().toISOString());
#
#   document.getElementById("mission-2-complete-message").innerHTML =
#     "🔓 Mission 3 unlocked! Badge added to your gallery.";
# }
# </script>
# ```

# %% [markdown]
# ```{admonition} 🎮 Mission Progress
# :class: note, dropdown
#
# **Your Journey**
#
# 🟢 **Mission 1: Locate & Retrieve Data** ← *Current*
# 🟢 Mission 2: Inspect the Package 🔒
# ⚪ Mission 3: Understand the Data 🔒
# ⚪ Mission 4: Generate Insights 🔒
# ⚪ Mission 5: Create Visual Evidence 🔒
# ⚪ Mission 6: Map the City 🔒
# ⚪ Mission 7: Extend the Analysis 🔒
# ⚪ Final Mission: Tell the Data Story 🔒
#
# **Progress:** ▰▰▱▱▱▱▱▱ 1/8 Complete

# %% [markdown]
# ```{admonition}  🚧 Next Mission Preview
# :class: note, dropdown
#
# 🧠 Mission 3: Understand the Data
#
# This mission is currently under construction.
#
# Soon, you will learn how to:
#
# - interpret variables and indicators
# - identify meaningful attributes
# - distinguish observations from metadata
# - evaluate data quality before analysis
#
# 🔍 The next phase of your investigation will focus on understanding what the data actually represents.
#
# Stay tuned...
# ```

# %% [markdown]
# ```{raw} html
# </div>
#
# <script>
# const mission1Completed =
#   localStorage.getItem("urban_data_mission_1_completed");
#
# if (mission1Completed === "true") {
#
#   document.getElementById("mission-2-protected-content").style.display = "block";
#
#   document.getElementById("mission-2-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#       <p>Welcome back, Urban Data Investigator.</p>
#       <p>You completed Mission 1 and can now continue to Mission 2.</p>
#     </div>
#   `;
#
# } else {
#
#   document.getElementById("mission-2-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#       <p>This mission is locked.</p>
#       <p>Complete <strong>Mission 1: Locate and Retrieve the Dataset</strong> first.</p>
#       <p>Then return here to continue your investigation.</p>
#     </div>
#   `;
#
# }
# </script>
# ```
