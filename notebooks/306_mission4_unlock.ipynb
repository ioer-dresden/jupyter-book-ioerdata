# %% [markdown]
# # Generate Insights
# ```{raw} html
# <div id="mission-4-gate"></div>
#
# <script>
# const mission3Completed =
#   localStorage.getItem("urban_data_mission_3_completed");
#
# if (mission3Completed === "true") {
#
#   document.getElementById("mission-4-gate").innerHTML = `
#     <div class="admonition tip">
#       <p class="admonition-title">🔓 Mission Unlocked</p>
#
#       <p>Welcome back, Urban Data Investigator.</p>
#
#       <p>
#       You completed <strong>Mission 3: Understand the Data</strong>
#       and earned the <strong>Data Interpreter</strong> badge.
#       </p>
#
#       <p>
#       Now it is time to put that knowledge to work. In this mission,
#       you will explore key indicators, compare values, and uncover
#       your first insights from the data.
#       </p>
#
#       <p style="margin-top: 16px;">
#         <a href="307_mission4_content.html"
#            style="display: inline-block;
#                   padding: 12px 18px;
#                   background-color: #1565C0;
#                   color: white;
#                   text-decoration: none;
#                   border-radius: 8px;
#                   font-weight: bold;">
#           🚀 Start Mission 4
#         </a>
#       </p>
#     </div>
#   `;
#
# } else {
#
#   document.getElementById("mission-4-gate").innerHTML = `
#     <div class="admonition warning">
#       <p class="admonition-title">🔒 Mission Locked</p>
#
#       <p>This mission is currently locked.</p>
#
#       <p>
#       Complete <strong>Mission 3: Understand the Data</strong>
#       before continuing.
#       </p>
#
#       <p>
#       Return to Mission 3 and click
#       <strong>Complete Mission 3</strong> at the end of the page.
#       </p>
#     </div>
#   `;
#
# }
# </script>
