# %% [markdown]
# <div style="display: flex; justify-content: flex-end; align-items: center; width: 100%;">
#     <!-- DOI Badge -->
#     <a href="https://TBD" style="margin-left: 10px;">
#         <img src="https://ioerdata.training.fdz.ioer.info/doi.svg" alt="Digital Object Identifier">
#     </a>
#     <!-- Version Badge -->
#     <a href="https://gitlab.hrz.tu-chemnitz.de/ioer/fdz/training/jupyter-book-ioerdata" style="margin-left: 10px;">
#         <img src="https://ioerdata.training.fdz.ioer.info/version.svg" alt="Version Reference">
#     </a>
# </div>

# %% [markdown]
# # Home

# %% [markdown]
# <!--
# <div class="fig-no-shadow" style="text-align: center;">
#     <img src="../_static/images/dverse_h.svg" width="100%" style="display: inline-block">
# </div>
# -->

# %% [markdown]
# <div class="fig-no-shadow" style="text-align: center;">
#     <img src="../_static/images/h_2.svg" width="100%" style="display: inline-block">
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="../_static/images/h_2.svg" width="100%" alt="ioerDATA training">
# </div>
#
# Welcome! 👋
#
# This hands-on training shows you how to work with research data from [ioerDATA](https://data.fdz.ioer.de/) using **Python and Jupyter notebooks**.
#
# You will move step by step from finding a dataset to understanding, analysing, and visualising it.

# %% [markdown]
# ---
# # 🔍 Questions
#
# By working through this training, we will answer:
#
# >- How can I access research data from ioerDATA using Python?
# >- What is inside a downloaded dataset or replication package?
# >- How can I understand its files, variables, and metadata?
# >- How can I analyse and visualise spatial research data?
# >- How can I make my workflow reproducible?

# %% [markdown]
# ---
# # 🎯 Learning objectives
#
# By the end of the training, you will be able to:
#
# >- access datasets through the ioerDATA API
# >- download research data with Python
# >- inspect files and metadata
# >- work with spatial data and GeoPackages
# >- explore indicators and create visualisations
# >- document a reproducible research workflow

# %% [markdown]
# ---
# # What is ioerDATA?
#
# [ioerDATA](https://data.fdz.ioer.de/) is the research data publication repository of the [Leibniz Institute of Ecological Urban and Regional Development (IOER)](https://www.ioer.de/en/).
#
# It provides access to research datasets, code, documentation, and replication packages for spatial, environmental, and socio-economic research.
#
# Throughout this training, we use real ioerDATA research data to learn by doing.

# %% [markdown]
# ---
# # How to use this book
#
# You can use the training at three levels:
#
# >1. Learn
#
# Read the explanations and follow the examples step by step.
#
# **No prior Python experience is required.**
#
# >2. Run
#
# Copy and run the code examples to reproduce the analyses, maps, and visualisations.
#
# >3. Extend
#
# Modify the examples to explore other indicators, datasets, or research questions.

# %% [markdown]
# > 💡 **New to Python?**
# >
# > You do not need to understand every line of code immediately.
# >
# > Start by running an example, look at the result, and then experiment by changing one small thing at a time.

# %% [markdown]
# ---
# # Choose how you want to work
#
# You can **read the book without installing anything**.
#
# To run and modify the notebooks, choose the environment that best fits your needs.

# %% [markdown]
# # Run in your browser
#
# For a quick start, use a browser-based Jupyter environment.
#
# >- **Jupyter4NFDI** — run notebooks online using supported academic credentials
# >- **Google Colab** — open and run compatible notebooks directly in your browser
#
# See the [Jupyter environment guide](notebooks/102_jupyter_notebooks.html) for setup instructions.

# %% [markdown]
# # Reproduce the complete workflow
#
# For a more controlled and reproducible environment, use the **Carto-Lab Docker environment**.
#
# This option is useful when you want to reproduce the full software environment used for the training.
#
# You can also explore the available [CartoLab environments](https://cartolab.fdz.ioer.info/environments/#).

# %% [markdown]
# # Work locally
#
# If you already use Python or Jupyter, you can clone the complete training repository and work with the notebooks locally.
#
# [View the training repository](https://gitlab.hrz.tu-chemnitz.de/ioer/fdz/training/jupyter-book-ioerdata)

# %% [markdown]
# > ℹ️ **Need help?**
# >
# > If you need support with the training environment, contact the **FDZ-IOER team** at [fdz@ioer.de](mailto:fdz@ioer.de).

# %% [markdown]
# ---
#
# ## 🕵️ Prefer a challenge?
#
# ### Become an Urban Data Investigator
#
# Want to learn by solving missions instead?
#
# Follow the same research workflow as a sequence of challenges:
#
# **🔎 Find → 📥 Retrieve → 🧠 Understand → 📊 Analyse → 🗺️ Visualise → 🔁 Reproduce**
#
# Each mission builds on what you discovered in the previous one.
#
# 👉 **[Start the Urban Data Investigator](notebooks/301_mission1_content)**
#
# ---

# %% [markdown]
# # What will we work with?
#
# The training uses a real ioerDATA replication package on **climate regulation in cities**.
#
# We will explore urban green infrastructure and related indicators while learning how research data moves from a repository into a reproducible Python workflow.
#
# The focus is not only on getting the code to run — but also on understanding what the data means.

# %% [markdown]
# # The workflow
#
# During the training, we will gradually build this workflow:
#
# >**ioerDATA**
#
# >↓
#
# >**Find a dataset**
#
# >↓
#
# >**Access it through the API**
#
# >↓
#
# >**Download the replication package**
#
# >↓
#
# >**Inspect files and metadata**
#
# >↓
#
# >**Explore and analyse the data**
#
# >↓
#
# >**Create visualisations and maps**
#
# >↓
#
# >**Document a reproducible workflow**

# %% [markdown]
# ---
# # About this training
#
# This training was developed by the **IOER Research Data Center (IOER RDC)** to provide practical guidance for working with research data from ioerDATA.
#
# It is designed for students, researchers, practitioners, and anyone interested in learning reproducible spatial-data workflows with Python and Jupyter notebooks.
#
# The training builds on the earlier [Guide on Spatial and Biodiversity Data](https://training.fdz.ioer.info/intro.html).
# ---

# %%
<div style="text-align: center; margin-top: 2rem;">

<img
    class="light-img logo-img"
    src="../_static/images/FDZ-Logo_EN_RGB-clr_bg-sol_mgn-full_h200px_web.svg"
    width="260"
    alt="FDZ-IOER logo">

<img
    class="dark-img logo-img"
    src="../_static/images/FDZ-Logo_EN_RGB-wht_bg-tra_mgn-full_h200px_web.svg"
    width="260"
    alt="FDZ-IOER logo">

<br><br>

<img
    class="light-img logo-img"
    src="../_static/images/NFDI_4_Biodiversity___Logo_Positiv_Kopie.png"
    width="340"
    alt="NFDI4Biodiversity logo">

<img
    class="dark-img logo-img"
    src="../_static/images/NFDI_4_Biodiversity___Logo_Negativ_Kopie.png"
    width="340"
    alt="NFDI4Biodiversity logo">

</div>

# %% [markdown]
# <div style="text-align: center; margin-top: 2rem;">
#
# <img
#     src="../_static/images/FDZ-Logo_EN_RGB-clr_bg-sol_mgn-full_h200px_web.svg"
#     width="260"
#     alt="FDZ-IOER logo">
#
# <br><br>
#
# <img
#     src="../_static/images/NFDI_4_Biodiversity___Logo_Positiv_Kopie.png"
#     width="340"
#     alt="NFDI4Biodiversity logo">
#
# </div>

# %% [markdown]
# ```{admonition} Overview
# :class: dropdown
#
# <div style="display: flex; gap: 2rem;">
#
# <div style="flex: 1;">
#
# <h3 style="color:#1f77b4; border-bottom: 2px solid #1f77b4; padding-bottom: 4px;">
# 🔍 Questions
# </h3>
#
# - How can I access research data from ioerDATA programmatically?
# - How can I understand downloaded data and metadata?
# - How can I create reproducible visualisations using Python?
#
# </div>
#
# <div style="flex: 1;">
#
# <h3 style="color:#1f77b4; border-bottom: 2px solid #1f77b4; padding-bottom: 4px;">
# 🎯 Objectives
# </h3>
#
# - Understand data access through ioerDATA
# - Download data using Python
# - Inspect data and metadata
# - Understand data structure
# - Create visualisations
# - Document reproducible workflows
#
# </div>
#
# </div>

# %% [markdown]
# ```{admonition} Introduction
# :class: note
#
# Welcome to this hands-on course from [ioerDATA](https://data.fdz.ioer.de/) to insight! 🎉
#
# **ioerDATA** is the institutional research‑data publication repository of the [Leibniz Institute of Ecological Urban and Regional Development (IOER)](https://www.ioer.de/en/).
# In this course, you will learn how to work with real research data from ioerDATA using Python in a Jupyter Notebook environment provided by CartoLab.
#
# The training is inspired by the teaching philosophy of the [IOER Research Data Center (IOER RDC)](https://ioer-fdz.de/en/): learning by doing, transparency in data handling, and reproducible research workflows.
#
# This Jupyter notebook is designed to help students, researchers, scientists, and enthusiasts get started with data-driven research. Whether you're a beginner or an experienced data scientist, this book will help you fetch data programmatically, understand its structure and metadata, and build visualisations to derive insights from IOER’s geospatial datasets.
# ```

# %% [markdown]
# ```{admonition} Content
# :class: note
# Our goal is to promote open science by providing access to the ioerDATA programmatically using its API (Application Programming Interface), which allows you to:
# - **Download** and analyse data from our repository.
# - **Explore** data programmatically using your preferred programming language (the examples in this course use Python).
#
# ioerData is an open research data repository operated by the [Leibniz Institute of Ecological Urban and Regional Development (IOER)](https://www.ioer.de/). It provides access to datasets, codes, and documentation related to spatial, environmental, and socio-economic research.
#
# Our datasets are openly accessible and reusable, adhering to the **FAIR** (Findable, Accessible, Interoperable, Reusable) principles.
# ```

# %% [markdown]
# ```{admonition} Who Can Use This Jupyter Book?
# :class: tip, dropdown
#
# This Jupyter Book is designed for learners with different levels of experience, from beginners to advanced users.
#
# **Learn**: Use this material as a self-paced learning resource to understand:
#
# - ioerDATA and replication packages
# - spatial data and GeoPackages
# - data analysis and visualisation
# - reproducible research workflows
#
# No prior Python experience is required to follow the explanations.
#
# **Run**: All examples can be copied and executed with minimal changes.
# Developers can:
#
# - run the code as snippets copied or by accessing the full git repo [here](https://gitlab.hrz.tu-chemnitz.de/ioer/fdz/training/jupyter-book-ioerdata)
# - run the "full" reproducibility pipeline with [Carto-Lab Docker](https://stag.ioerdata.training.fdz.ioer.info/notebooks/102_jupyter_notebooks.html#carto-lab-docker) v0.28.0 version
# - reproduce the maps and visualisations
# - adapt the examples to your own datasets
#
# **Extend**: Advanced users can modify the notebooks to:
#
# - analyse different indicators
# - combine multiple datasets
# - create new visualisations
# - develop their own workflows
#
# **Working Environment**
#
# To run the notebooks interactively, you can:
#
# - use the **reproducibility light**
#   - run the notebook directly in browser via [Jupyter4NFDI](https://hub.nfdi-jupyter.de/hub/login)
#   - use your academic credentials to login
#   - check [guide](https://stag.ioerdata.training.fdz.ioer.info/notebooks/102_jupyter_notebooks.html#jupyter4nfdi) if needed
# - start from the [CartoLab environments](https://cartolab.fdz.ioer.info/environments/#)
# - set up your own local Python environment
#
# If you need support with the setup or would like access to a suitable environment, please contact the FDZ-IOER team at <a href="mailto:fdz@ioer.de">fdz@ioer.de</a>.
# ```

# %% [markdown]
# ```{admonition} Tip
# :class: hint, dropdown
# A basic understanding of Python is beneficial but not required. Readers will need access to a computer with internet connectivity and the ability to run Jupyter Notebooks is recommended.
# ```

# %% [markdown]
# ```{admonition} How to use this book?
# :class: note
# You can use this Jupyter Book in different ways depending on your needs.
#
# If you are new to the topic, follow the chapters in order. If you are working on a specific project, you can reuse individual explanations, code snippets, or complete workflows as building blocks for your own analysis.
# ```

# %% [markdown]
# ```{admonition} About the Project
# :class: note, dropdown
#
# This project is inspired by [guide on spatial and biodiversity data](https://training.fdz.ioer.info/intro.html).
#
# The goal is to provide hands-on training materials for working with ioerDATA. Participants learn how to access datasets, understand replication packages, perform basic analyses, and create spatial visualisations using Python and Jupyter notebooks.
#
# Want to have some fun while learning? Then check our [Urban Data Investigator](https://stag.ioerdata.training.fdz.ioer.info/notebooks/ioerdata_api/30_find_the_dataset.html)
# ```

# %% [markdown]
# # License and Citation
#
# ```{note}
# The instructional material of this Jupyter Book is made available under the [Creative Commons Attribution 4.0 International](https://spdx.org/licenses/CC-BY-4.0.html) (CC BY 4.0) license.
#
# This includes all text and drawings unless otherwise noted.
#
# Except where otherwise noted, the code provided in this Jupyter Book is made available under the [MIT License](https://spdx.org/licenses/MIT.html).

# %% [markdown]
# # Recommended citation
# ```{note}
#
# **Oyshi, Marzan Tasnim, Dunkel, Alexander, Nieswand, Maria, (2026).** _From IOER Dataverse to insight a Python and JupyterLab workflow_. Leibniz Institute of Ecological Urban and Regional Development (IOER), [URL](https://training.fdz.ioer.info/), [DOI](https://doi.org/10.71830/6ILS40).
# ```

# %% [markdown]
# **Publication Date**: June 2026

# %% [markdown]
# <div class="fig-no-shadow" style="text-align: center;">
#     <img class="light-img logo-img" src="../_static/images/FDZ-Logo_EN_RGB-clr_bg-sol_mgn-full_h200px_web.svg" width="300">
#     <img class="dark-img logo-img" src="../_static/images/FDZ-Logo_EN_RGB-wht_bg-tra_mgn-full_h200px_web.svg" width="300">
#     <img class="light-img logo-img" src="../_static/images/NFDI_4_Biodiversity___Logo_Positiv_Kopie.png" width="400" style="margin-right: 20px;">
#     <img class="dark-img logo-img" src="../_static/images/NFDI_4_Biodiversity___Logo_Negativ_Kopie.png" width="400" style="margin-right: 20px;">
# </div>
